# %%
import pandas as pd

# %% [markdown]
# # Apply

# %%
titanic_df = pd.read_csv("Titanic_data.csv")

# %% [markdown]
# # Aggregate

# %% [markdown]
# # FillNan values

# %%
# Group by 'initial' and calculate the mean age for each group
mean_age_by_initial = df.groupby('initial')['age'].transform('mean')

# Fill NaN values in the 'age' column with the corresponding mean age for the same initial
df['age'] = df['age'].fillna(mean_age_by_initial)

print(df)
