# %%
import pandas as pd

# %%
titanic_df = pd.read_csv("Titanic_data.csv")

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Dropping column

titanic_df.drop('PassengerId', axis = 1, inplace = True)
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
# Dropping row

titanic_df(#RowNUmber, )

# %%
last_names = [name.split(",")[0] for name in titanic_df.Name]
titanic_df['First Name'] = last_names

# %%
first_names = [name.split(",")[1] for name in titanic_df.Name]
titanic_df['First Name'] = first_names

# %%
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#                                     First Name
# 0                              Mr. Owen Harris
# ...

# %%
first_names = [name.split(",")[1][0:5] for name in titanic_df.Name]
first_names
# Out:
# [' Mr. ',
#  ' Mrs.',
#  ' Miss',
#  ' Mrs.',
#  ' Mr. ',
#  ' Mr. ',
#  ' Mr. ',
#  ' Mast',
#  ' Mrs.',
#  ' Mrs.',
#  ' Miss',
#  ' Miss',
#  ' Mr. ',
#  ' Mr. ',
#  ' Miss',
#  ' Mrs.',
#  ' Mast',
#  ' Mr. ',
#  ' Mrs.',
#  ' Mrs.',
#  ' Mr. ',
#  ' Mr. ',
#  ' Miss',
#  ' Mr. ',
#  ' Miss',
#  ' Mrs.',
#  ' Mr. ',
#  ' Mr. ',
#  ' Miss',
#  ' Mr. ',
#  ' Don.',
#  ' Mrs.',
#  ' Miss',
#  ' Mr. ',
#  ' Mr. ',
#  ' Mr. ',
#  ' Mr. ',
#  ' Mr. ',
#  ' Miss',
#  ' Miss',
#  ' Mrs.',
#  ' Mrs.',
#  ' Mr. ',
#  ' Miss',
#  ' Miss',
#  ' Mr. ',
#  ' Mr. ',
#  ' Miss',
#  ' Mr. ',
#  ' Mrs.',
#  ' Mast',
#  ' Mr. ',
#  ' Mrs.',
#  ' Mrs.',
#  ' Mr. ',
#  ' Mr. ',
#  ' Miss',
#  ' Mr. ',
#  ' Miss',
#  ' Mast',
#  ' Mr. ',
#  ' Miss',
#  ' Mr. ',
#  ' Mast',
#  ' Mr. ',
#  ' Mast',
#  ' Mrs.',
#  ' Mr. ',
#  ' Miss',
#  ' Mr. ',
#  ' Mr. ',
#  ' Miss',
#  ' Mr. ',
#  ' Mr. ',
#  ' Mr. ',
#  ' Mr. ',
#  ' Mr. ',
#  ' Mr. ',
#  ' Mast',
#  ' Miss',
#  ' Mr. ',
#  ' Mr. ',
#  ' Miss',
# ...

# %%
Salutation = [name.split(",")[1].split(".")[0] for name in titanic_df.Name]
titanic_df['Salutation'] = Salutation

# %%
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#                                     First Name Salutation
# ...

# %%
# inserting in a row

titanic_df.loc[0,'Cabin'] = 'C23'

# %%
titanic_df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   C23        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#                                     First Name Salutation
# ...

# %%
titanic_df.drop(900, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 titanic_df.drop(900, inplace = True)
#
# File ~/My_programs/Data-Science---Skill-Shikshya/myenv/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %% [markdown]
# ## Handling NaN or Null value

# %%
titanic_df.isna().sum()
# Out:
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age           177
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin         686
# Embarked        2
# First Name      0
# Salutation      0
# dtype: int64

# %% [markdown]
# ## imputation

# %%
age_mean = titanic_df.Age.mean()
age_mean
# Out:
# np.float64(29.69911764705882)

# %%
titanic_df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
