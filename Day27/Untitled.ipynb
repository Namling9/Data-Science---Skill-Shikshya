# %% [markdown]
# # Manipulation and Cleaning Data

# %%
import pandas as pd

# %%
df = pd.read_csv('Stats survey.csv')

# %%
df.head()
# Out:
#                    Timestamp Your Sex?  \
# 0  2024/03/07 5:12:01 pm EET    Female
# 1  2024/03/07 5:12:08 pm EET      Male
# 2  2024/03/07 5:12:25 pm EET      Male
# 3  2024/03/07 5:12:28 pm EET      Male
# 4  2024/03/07 5:13:00 pm EET    Female
#
#    Your Matric (grade 12) Average/ GPA (in %)  \
# 0                                        76.0
# 1                                        89.0
# 2                                        76.0
# 3                                        89.0
# 4                                        74.0
#
#   What year were you in last year (2023) ?  \
# 0                                 2nd Year
# 1                                 2nd Year
# 2                                 1st Year
# 3                                 2nd Year
# 4                                 2nd Year
#
#   What faculty does your degree fall under?  \
# 0                    Arts & Social Sciences
# 1            Economic & Management Sciences
# ...

# %%
df.drop(['Timestamp'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#   Your Sex?  Your Matric (grade 12) Average/ GPA (in %)  \
# 0    Female                                        76.0
# 1      Male                                        89.0
# 2      Male                                        76.0
# 3      Male                                        89.0
# 4    Female                                        74.0
#
#   What year were you in last year (2023) ?  \
# 0                                 2nd Year
# 1                                 2nd Year
# 2                                 1st Year
# 3                                 2nd Year
# 4                                 2nd Year
#
#   What faculty does your degree fall under?  \
# 0                    Arts & Social Sciences
# 1            Economic & Management Sciences
# 2                              AgriSciences
# 3                               Engineering
# 4                    Arts & Social Sciences
#
#    Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)  \
# ...

# %% [markdown]
# ## outlier

# %%
def handling_outlier(df: pd.df, nums_columns):
    for every in df:
        q1 = df[every].quantile(q1)

# %%
nan_accom = df['Your Accommodation Status Last Year (2023)'].isna()
print(nan_accom)

print(df.loc[nan_accom])
filled_accom = nan_accom.fillna('unknown')
filled_accom
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 401    False
# 402    False
# 403    False
# 404    False
# 405    False
# Name: Your Accommodation Status Last Year (2023), Length: 406, dtype: bool
#     Your Sex?  Your Matric (grade 12) Average/ GPA (in %)  \
# 8        Male                                        89.0
# 9        Male                                        83.0
# 10     Female                                        75.0
# 14       Male                                        78.0
# 76     Female                                        76.0
# 77     Female                                        87.0
# 114    Female                                        83.0
# 115    Female                                        84.0
# 153    Female                                        85.0
# 163    Female                                        69.0
# 171    Female                                        73.0
# ...
